# %%
from IPython.display import display, Image

# %% [markdown]
# # Big Picture of Calculus

# %%
display(Image(filename='./pic/MIT_Highlights_of_Calculus_1.png'))

# %%
display(Image(filename='./pic/MIT_Highlights_of_Calculus_2.png'))

# %%
display(Image(filename='./pic/MIT_Highlights_of_Calculus_3.png'))

# %%
display(Image(filename='./pic/MIT_Highlights_of_Calculus_4.png'))

# %%
display(Image(filename='./pic/MIT_Highlights_of_Calculus_5.png'))

# %%
display(Image(filename='./pic/MIT_Highlights_of_Calculus_6.png'))

# %%
display(Image(filename='./pic/MIT_Highlights_of_Calculus_7.png'))

# %%
display(Image(filename='./pic/MIT_Highlights_of_Calculus_8.png'))

# %%
display(Image(filename='./pic/MIT_Highlights_of_Calculus_9.png'))

# %%
display(Image(filename='./pic/MIT_Highlights_of_Calculus_10.png'))

# %%
display(Image(filename='./pic/MIT_Highlights_of_Calculus_11.png'))

# %%
display(Image(filename='./pic/MIT_Highlights_of_Calculus_12.png'))

# %%
display(Image(filename='./pic/MIT_Highlights_of_Calculus_13.png'))

# %%
display(Image(filename='./pic/MIT_Highlights_of_Calculus_14.png'))

# %%
display(Image(filename='./pic/MIT_Highlights_of_Calculus_15.png'))

# %%
display(Image(filename='./pic/MIT_Highlights_of_Calculus_16.png'))

# %%
display(Image(filename='./pic/MIT_Highlights_of_Calculus_17.png'))
